# %% [markdown]
# # En este bloque de código, vamos a procesar los datasets para tener la información de las consultas preparadas.

# %%
import main

try :
    main.procesar_aeropuertos()
    main.procesar_conectividad()
    main.procesar_lagos()
    main.procesar_censo()
    print ("Archivos procesados")
except:
    print ("Ha ocurrido un error procesando los archivos")
# Out:
# Archivos procesados

# %% [markdown]
# # Consulta #1: mostrar los diferentes tipos de aeropuertos según la columna 'type'.

# %%
from querys import consulta_1
from pathlib import Path

path_aeropuertos =  Path ("new_datasets") / "ar-airports.csv"
consulta_1.obtener_tipos_aeropuerto(path_aeropuertos)
# Out:
# Tipos de aeropuerto encontrados: ['balloonport', 'small_airport', 'medium_airport', 'large_airport', 'closed', 'heliport']
# ['balloonport',
#  'small_airport',
#  'medium_airport',
#  'large_airport',
#  'closed',
#  'heliport']

# %% [markdown]
# # Consulta #2 : Los aeropuertos de una elevación, (bajo, medio, alto) cuya especificación se permita modificar fácilmente, evaluando la columna creada 'elevation_name'.

# %%
from querys import consulta_2

consulta_2.main()
# Out:
# Seleccione una opción:
# 1. Bajo
# 2. Medio
# 3. Alto
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from querys import consulta_2
# ----> 3 consulta_2.main()
#
# File c:\Users\Limbo\Documents\ProyectoPython\querys\consulta_2.py:70, in main()
#      68 archivo_csv = 'new_datasets/ar-airports.csv'  # Ruta temporal de archivo (Cambiar con Path)
#      69 mostrar_menu()
# ---> 70 opcion_elegida = elegir_opcion()
#      71 print("Ha elegido la altura:", opcion_elegida)
#      72 procesar_archivo(archivo_csv, opcion_elegida)
#
# File c:\Users\Limbo\Documents\ProyectoPython\querys\consulta_2.py:29, in elegir_opcion()
#      18 def elegir_opcion():
#      20     """
#      21     Solicita al usuario que ingrese una opción del menú y la valida.
#      22
#    (...)
#      27
#      28     """
# ---> 29     opcion = input("Ingrese el número de la opción que desea: ")
#      30     if opcion == '1':
#      31         return "bajo"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
