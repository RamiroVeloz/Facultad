# %% [markdown]
# Se importa proceso_3, que procesa el dataset lagos_arg. Se le envia como parametro a la funcion la ruta donde esta el archivo y donde debe guardar el procesado.

# %%
from modulos import proceso_3
from modulos import proceso_2
from pathlib import Path
##ruta_csv = Path ("datasets") / "lagos_arg.csv"
##proceso_3.procesar_dataset_lagos(ruta_csv, "datasets_procesados")
ruta_conectividad = Path ("datasets") / "Conectividad_Internet.csv"
proceso_2.generar_copia (ruta_conectividad)
proceso_2.procesar_conectividad()
